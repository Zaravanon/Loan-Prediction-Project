# %% [markdown]
# # Importing Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVC
import xgboost as xgb

# %%
train_original = pd.read_csv(r'C:\Users\Saravanan\Documents\Kaggle Datasets & Projects\Loan Prediction project\train_dataset.csv')
test_original = pd.read_csv(r'C:\Users\Saravanan\Documents\Kaggle Datasets & Projects\Loan Prediction project\test_dataset.csv')

train_dataset = pd.read_csv(r'C:\Users\Saravanan\Documents\Kaggle Datasets & Projects\Loan Prediction project\train_dataset.csv')
test_dataset = pd.read_csv(r'C:\Users\Saravanan\Documents\Kaggle Datasets & Projects\Loan Prediction project\test_dataset.csv')

# %%
train_dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
train_dataset.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
train_dataset.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
test_dataset.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
train_dataset.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# # Exploratory Data Analysis

# %%
dataset = [train_dataset,test_dataset]

# %%
train_dataset['Gender'].value_counts(normalize=True).plot.bar(title="Gender")
train_dataset['Gender'].value_counts(normalize=True)*100
# Out:
# Male      81.364393
# Female    18.635607
# Name: Gender, dtype: float64

# %%
train_dataset['Married'].value_counts(normalize=True).plot.bar(title="Married")
train_dataset['Married'].value_counts(normalize=True)*100
# Out:
# Yes    65.139116
# No     34.860884
# Name: Married, dtype: float64

# %%
train_dataset['Dependents'].value_counts(normalize=True).plot.bar(title="Dependents")
train_dataset['Dependents'].value_counts(normalize=True)*100
# Out:
# 0     57.595993
# 1     17.028381
# 2     16.861436
# 3+     8.514190
# Name: Dependents, dtype: float64

# %%
train_dataset['Education'].value_counts(normalize=True).plot.bar(title="Education")
train_dataset['Education'].value_counts(normalize=True)*100
# Out:
# Graduate        78.175896
# Not Graduate    21.824104
# Name: Education, dtype: float64

# %%
train_dataset['Self_Employed'].value_counts(normalize=True).plot.bar(title="Self_Employed")
train_dataset['Self_Employed'].value_counts(normalize=True)*100
# Out:
# No     85.910653
# Yes    14.089347
# Name: Self_Employed, dtype: float64

# %%
train_dataset['Property_Area'].value_counts(normalize=True).plot.bar(title="Property_Area")
train_dataset['Property_Area'].value_counts(normalize=True)*100
# Out:
# Semiurban    37.947883
# Urban        32.899023
# Rural        29.153094
# Name: Property_Area, dtype: float64

# %%
train_dataset['Credit_History'].value_counts(normalize=True).plot.bar(title="Credit_History")
train_dataset['Credit_History'].value_counts(normalize=True)*100
# Out:
# 1.0    84.219858
# 0.0    15.780142
# Name: Credit_History, dtype: float64

# %%
figure = plt.figure(figsize = (20,6))
ax1 = figure.add_subplot(1,2,1)
sns.distplot(train_dataset['ApplicantIncome'],color='r',bins=100)
plt.title("Applicant Income Distribution",fontsize=25)
ax2 =figure.add_subplot(1,2,2)
plt.boxplot(train_dataset['ApplicantIncome'],notch=True)
plt.title("Applicant Income Boxplot",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Applicant Income Boxplot')

# %%
figure = plt.figure(figsize = (20,6))
ax1 = figure.add_subplot(1,2,1)
sns.distplot(train_dataset['CoapplicantIncome'],color='r',bins=100)
plt.title("Coapplicant Income Distribution",fontsize=25)
ax2 =figure.add_subplot(1,2,2)
plt.boxplot(train_dataset['CoapplicantIncome'],notch=True)
plt.title("Coapplicant Income Boxplot",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Coapplicant Income Boxplot')

# %%
figure = plt.figure(figsize = (20,6))
ax1 = figure.add_subplot(1,2,1)
sns.distplot(train_dataset['LoanAmount'],color='r',bins=100)
plt.title("Loan Amount Distribution",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Loan Amount Distribution')

# %%
train_dataset['LoanAmount'].plot.box(notch=True)
# Out:
# <AxesSubplot:>

# %%
pd.crosstab(train_dataset['Credit_History'],train_dataset['Loan_Status'],normalize='index')*100
# Out:
# Loan_Status             N          Y
# Credit_History
# 0.0             92.134831   7.865169
# 1.0             20.421053  79.578947

# %%
credithistory = pd.crosstab(train_dataset['Credit_History'],train_dataset['Loan_Status'])
credithistory.plot(kind="bar",stacked=True,figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Credit_History'>

# %%
train_dataset.groupby('Loan_Status')['ApplicantIncome'].mean()
# Out:
# Loan_Status
# N    5446.078125
# Y    5384.068720
# Name: ApplicantIncome, dtype: float64

# %%
bins = [0,10000,15000,20000,81000]
labels = ["low","medium","high","very high"]

train_dataset['App_Income_Bin'] = pd.cut(train_dataset['ApplicantIncome'],bins,labels=labels)

# %%
train_dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status App_Income_Bin
# 0             1.0         Urban           Y            low
# ...

# %%
pd.crosstab(train_dataset['App_Income_Bin'],train_dataset['Loan_Status'],normalize="index")*100
# Out:
# Loan_Status             N          Y
# App_Income_Bin
# low             31.138790  68.861210
# medium          37.037037  62.962963
# high            23.076923  76.923077
# very high       33.333333  66.666667

# %%
train_dataset['Loan_term_years'] = train_dataset['Loan_Amount_Term']/12

# %%
train_dataset['Loan_term_years'].describe()
# Out:
# count    600.000000
# mean      28.500000
# std        5.426701
# min        1.000000
# 25%       30.000000
# 50%       30.000000
# 75%       30.000000
# max       40.000000
# Name: Loan_term_years, dtype: float64

# %%
train_dataset['Loan_term_years'].value_counts().sort_index().plot.bar(color="red")
# Out:
# <AxesSubplot:>

# %%
pd.crosstab(train_dataset['Loan_term_years'],train_dataset['Loan_Status']).sort_index()
# Out:
# Loan_Status        N    Y
# Loan_term_years
# 1.0                0    1
# 3.0                2    0
# 5.0                0    2
# 7.0                1    3
# 10.0               0    3
# 15.0              15   29
# 20.0               1    3
# 25.0               5    8
# 30.0             153  359
# 40.0               9    6

# %%
pd.crosstab(train_dataset['Property_Area'],train_dataset['Loan_Status'])
# Out:
# Loan_Status     N    Y
# Property_Area
# Rural          69  110
# Semiurban      54  179
# Urban          69  133

# %%
pd.crosstab(train_dataset['Property_Area'],train_dataset['Loan_Status'],normalize="index").round(decimals=2).plot.bar()
# Out:
# <AxesSubplot:xlabel='Property_Area'>

# %%
pd.crosstab(train_dataset['Self_Employed'],train_dataset['Loan_Status']).plot.bar()
# Out:
# <AxesSubplot:xlabel='Self_Employed'>

# %%
pd.crosstab(train_dataset['Self_Employed'],train_dataset['Loan_Status'],normalize=True)*100
# Out:
# Loan_Status            N          Y
# Self_Employed
# No             26.975945  58.934708
# Yes             4.467354   9.621993

# %%
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
#  13  App_Income_Bin     614 non-null    category
#  14  Loan_term_years    600 non-null    float64
# ...

# %%
pd.crosstab(train_dataset['Married'],train_dataset['Loan_Status']).plot.bar()
# Out:
# <AxesSubplot:xlabel='Married'>

# %%
pd.crosstab(train_dataset['Gender'],train_dataset['Loan_Status']).plot.bar()
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
pd.crosstab(train_dataset['Education'],train_dataset['Loan_Status']).plot.bar()
# Out:
# <AxesSubplot:xlabel='Education'>

# %%
train_dataset.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
#        'App_Income_Bin', 'Loan_term_years'],
#       dtype='object')

# %%
train_dataset = train_dataset.drop(columns = ['App_Income_Bin', 'Loan_term_years'])

# %%
correlation = train_dataset.corr()
correlation
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045306       -0.014715
# CoapplicantIncome         -0.059878       -0.002056
# LoanAmount                 0.039447       -0.008433
# Loan_Amount_Term           1.000000        0.001470
# Credit_History             0.001470        1.000000

# %%
train_dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
figure = plt.figure(figsize=(10,10))
sns.heatmap(correlation, annot=True,vmax=.8,cmap="coolwarm",square=True, figure=figure)
# Out:
# <AxesSubplot:>

# %%
train_dataset['Dependents'].replace("3+",3,inplace=True)
test_dataset['Dependents'].replace("3+",3,inplace=True)
train_dataset['Loan_Status'].replace("Y",1,inplace=True)
train_dataset['Loan_Status'].replace("N",0,inplace=True)

# %%
train_dataset.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes          3      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
correlation_matrix = train_dataset.corr()
figure = plt.figure(figsize=(10,10))
sns.heatmap(correlation_matrix, annot=True,vmax=.8,cmap="coolwarm",square=True, figure=figure)
# Out:
# <AxesSubplot:>

# %%
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 62.5+ KB

# %%
train_dataset['Gender'].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
train_dataset.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train_dataset.dropna(subset=['Married'],inplace=True)

# %%
train_dataset.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               0
# Dependents           12
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           21
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
test_dataset.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
train_dataset.Gender.value_counts(normalize=True)*100
# Out:
# Male      81.438127
# Female    18.561873
# Name: Gender, dtype: float64

# %%
null_features_cat = ['Gender','Dependents','Self_Employed','Loan_Amount_Term','Credit_History']

for i in null_features_cat:
    print(train_dataset[i].value_counts(normalize = True)*100)
    print(test_dataset[i].value_counts(normalize = True)*100)
# Out:
# Male      81.438127
# Female    18.561873
# Name: Gender, dtype: float64
# Male      80.337079
# Female    19.662921
# Name: Gender, dtype: float64
# 0    57.595993
# 1    17.028381
# 2    16.861436
# 3     8.514190
# Name: Dependents, dtype: float64
# 0    56.022409
# 2    16.526611
# 1    16.246499
# 3    11.204482
# Name: Dependents, dtype: float64
# No     85.837651
# Yes    14.162349
# Name: Self_Employed, dtype: float64
# No     89.244186
# Yes    10.755814
# Name: Self_Employed, dtype: float64
# 360.0    85.594640
# 180.0     7.370184
# 480.0     2.345059
# 300.0     2.177554
# 84.0      0.670017
# 240.0     0.502513
# 120.0     0.502513
# 36.0      0.335008
# 60.0      0.335008
# 12.0      0.167504
# Name: Loan_Amount_Term, dtype: float64
# 360.0    86.149584
# 180.0     6.094183
# 480.0     2.216066
# 300.0     1.939058
# 240.0     1.108033
# 84.0      0.831025
# 6.0       0.277008
# 120.0     0.277008
# 36.0      0.277008
# 350.0     0.277008
# 12.0      0.277008
# ...

# %%
nullmodefill = ['Gender','Dependents','Self_Employed','LoanAmount']
for i in nullmodefill:
    if train_dataset[i].dtype == "O":
        train_dataset[i].fillna(train_dataset[i].mode()[0], inplace=True)
        test_dataset[i].fillna(train_dataset[i].mode()[0], inplace=True)
    else:
        train_dataset[i].fillna(train_dataset[i].mean(), inplace=True)
        test_dataset[i].fillna(train_dataset[i].mean(), inplace=True)


train_dataset['Loan_Amount_Term'].fillna(train_dataset['Loan_Amount_Term'].mode()[0],inplace=True)
test_dataset['Loan_Amount_Term'].fillna(train_dataset['Loan_Amount_Term'].mode()[0],inplace=True)


train_dataset['Credit_History'].fillna(train_dataset['Credit_History'].mode()[0],inplace=True)
test_dataset['Credit_History'].fillna(train_dataset['Credit_History'].mode()[0],inplace=True)

# %%
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 611 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            611 non-null    object
#  1   Gender             611 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         611 non-null    object
#  4   Education          611 non-null    object
#  5   Self_Employed      611 non-null    object
#  6   ApplicantIncome    611 non-null    int64
#  7   CoapplicantIncome  611 non-null    float64
#  8   LoanAmount         611 non-null    float64
#  9   Loan_Amount_Term   611 non-null    float64
#  10  Credit_History     611 non-null    float64
#  11  Property_Area      611 non-null    object
#  12  Loan_Status        611 non-null    int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 66.8+ KB

# %%
test_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             367 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         367 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      367 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         367 non-null    float64
#  9   Loan_Amount_Term   367 non-null    float64
#  10  Credit_History     367 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
train_dataset.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 611 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            611 non-null    object
#  1   Gender             611 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         611 non-null    object
#  4   Education          611 non-null    object
#  5   Self_Employed      611 non-null    object
#  6   ApplicantIncome    611 non-null    int64
#  7   CoapplicantIncome  611 non-null    float64
#  8   LoanAmount         611 non-null    float64
#  9   Loan_Amount_Term   611 non-null    float64
#  10  Credit_History     611 non-null    float64
#  11  Property_Area      611 non-null    object
#  12  Loan_Status        611 non-null    int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 66.8+ KB

# %%
numerical_cols = ['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term']

figure1 = plt.figure(figsize=(20,10))
axes1 = figure1.add_subplot(221)
plt.boxplot(train_dataset['ApplicantIncome'],vert=False)
plt.title('Applicant Income',fontname="Times New Roman Bold")

axes2 = figure1.add_subplot(222)
plt.boxplot(train_dataset['CoapplicantIncome'],vert=False)
plt.title('Coapplicant Income',fontname="Times New Roman Bold")

axes3 = figure1.add_subplot(223)
plt.boxplot(train_dataset['LoanAmount'],vert=False)
plt.title("Loan Amount",fontname="Times New Roman Bold")

axes4 = figure1.add_subplot(224)
plt.boxplot(train_dataset['Loan_Amount_Term'],vert=False)
plt.title("Loan Amount Term",fontname="Times New Roman Bold")
# Out:
# Text(0.5, 1.0, 'Loan Amount Term')
# findfont: Font family ['Times New Roman Bold'] not found. Falling back to DejaVu Sans.

# %%
numerical_cols = ['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term']

figure1 = plt.figure(figsize=(20,10))
axes1 = figure1.add_subplot(221)
plt.scatter(train_dataset['ApplicantIncome'],train_dataset['Loan_Status'],color="red")
plt.title('Applicant Income',fontname="Times New Roman Bold")

axes2 = figure1.add_subplot(222)
plt.scatter(train_dataset['CoapplicantIncome'],train_dataset['Loan_Status'],color="blue")
plt.title('Coapplicant Income',fontname="Times New Roman Bold")


axes3 = figure1.add_subplot(223)
plt.scatter(train_dataset['LoanAmount'],train_dataset['Loan_Status'],color="yellow")
plt.title("Loan Amount",fontname="Times New Roman Bold")

axes4 = figure1.add_subplot(224)
plt.scatter(train_dataset['Loan_Amount_Term'],train_dataset['Loan_Status'],color="black")
plt.title("Loan Amount Term",fontname="Times New Roman Bold")
# Out:
# Text(0.5, 1.0, 'Loan Amount Term')

# %%
for i in dataset:
    for j in numerical_cols:
        print(j,'-',i[j].skew())
# Out:
# ApplicantIncome - 6.539513113994625
# CoapplicantIncome - 7.491531216657306
# LoanAmount - 2.677551679256059
# Loan_Amount_Term - -2.362414124216269
# ApplicantIncome - 8.441374954190996
# CoapplicantIncome - 4.257356934477602
# LoanAmount - 2.230575702708965
# Loan_Amount_Term - -2.709536758573826

# %%
figure1 = plt.figure(figsize=(20,10))
axes1 = figure1.add_subplot(221)
sns.distplot(train_dataset['ApplicantIncome'],color="red")

axes2 = figure1.add_subplot(222)
sns.distplot(train_dataset['CoapplicantIncome'],color="Violet")

axes3 = figure1.add_subplot(223)
sns.distplot(train_dataset['LoanAmount'],color="blue")

axes4 = figure1.add_subplot(224)
sns.distplot(train_dataset['Loan_Amount_Term'],color="green")
# Out:
# <AxesSubplot:xlabel='Loan_Amount_Term'>

# %%
train_dataset.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes          3      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.369492             360.0
# 1             4583             1508.0  128.000000             360.0
# ...

# %%
for i in dataset:
    print(i)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
dataset = [train_dataset,test_dataset]

# %%
for i in dataset:
    i['LoanAmountlog'] = np.log(i['LoanAmount'])
    #np.seterr(divide = 'ignore')

# %%
test_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             367 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         367 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      367 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         367 non-null    float64
#  9   Loan_Amount_Term   367 non-null    float64
#  10  Credit_History     367 non-null    float64
#  11  Property_Area      367 non-null    object
#  12  LoanAmountlog      367 non-null    float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 37.4+ KB

# %%
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 611 entries, 0 to 613
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            611 non-null    object
#  1   Gender             611 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         611 non-null    object
#  4   Education          611 non-null    object
#  5   Self_Employed      611 non-null    object
#  6   ApplicantIncome    611 non-null    int64
#  7   CoapplicantIncome  611 non-null    float64
#  8   LoanAmount         611 non-null    float64
#  9   Loan_Amount_Term   611 non-null    float64
#  10  Credit_History     611 non-null    float64
#  11  Property_Area      611 non-null    object
#  12  Loan_Status        611 non-null    int64
#  13  LoanAmountlog      611 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 71.6+ KB

# %%
train_dataset.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes          3      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.369492             360.0
# 1             4583             1508.0  128.000000             360.0
# ...

# %%
test_dataset.head(10)
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001015    Male     Yes          0      Graduate            No
# 1  LP001022    Male     Yes          1      Graduate            No
# 2  LP001031    Male     Yes          2      Graduate            No
# 3  LP001035    Male     Yes          2      Graduate            No
# 4  LP001051    Male      No          0  Not Graduate            No
# 5  LP001054    Male     Yes          0  Not Graduate           Yes
# 6  LP001055  Female      No          1  Not Graduate            No
# 7  LP001056    Male     Yes          2  Not Graduate            No
# 8  LP001059    Male     Yes          2      Graduate            No
# 9  LP001067    Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# ...

# %%
sns.distplot(train_dataset['LoanAmountlog'])
# Out:
# <AxesSubplot:xlabel='LoanAmountlog'>

# %%
train_dataset['Loan_Amount_Term'].value_counts()
# Out:
# 360.0    525
# 180.0     44
# 480.0     14
# 300.0     13
# 84.0       4
# 240.0      3
# 120.0      3
# 36.0       2
# 60.0       2
# 12.0       1
# Name: Loan_Amount_Term, dtype: int64

# %%
train_dataset['ApplicantIncome'].describe()
#train_dataset['CoapplicantIncome'].describe()
#train_dataset['Loan_Amount_Term'].describe()
# Out:
# count      611.000000
# mean      5399.513912
# std       6120.764249
# min        150.000000
# 25%       2875.500000
# 50%       3800.000000
# 75%       5790.000000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64

# %%
train_dataset.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       611.000000         611.000000  611.000000        611.000000
# mean       5399.513912        1627.972046  146.369492        342.324059
# std        6120.764249        2931.747971   84.240750         64.208419
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2875.500000           0.000000  100.000000        360.000000
# 50%        3800.000000        1213.000000  128.000000        360.000000
# 75%        5790.000000        2304.000000  165.000000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History  Loan_Status  LoanAmountlog
# count      611.000000   611.000000     611.000000
# mean         0.854337     0.685761       4.861175
# std          0.353057     0.464592       0.497624
# min          0.000000     0.000000       2.197225
# 25%          1.000000     0.000000       4.605170
# ...

# %%
test_dataset.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  367.000000        367.000000
# mean       4805.599455        1569.577657  136.272064        342.822888
# std        4910.685399        2334.232099   60.957624         64.658402
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  101.000000        360.000000
# 50%        3786.000000        1025.000000  126.000000        360.000000
# 75%        5060.000000        2430.500000  157.500000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History  LoanAmountlog
# count      367.000000     367.000000
# mean         0.839237       4.829169
# std          0.367814       0.416599
# min          0.000000       3.332205
# 25%          1.000000       4.615121
# 50%          1.000000       4.836282
# 75%          1.000000       5.059420
# ...

# %% [markdown]
# # Outlier Treatment

# %%
outlierfeatnum = ['ApplicantIncome','CoapplicantIncome']

def outliers_doctor_train(variable):
    quartile1= train_dataset[variable].quantile(0.25)
    print(quartile1)
    quartile3= train_dataset[variable].quantile(0.75)
    IQR = quartile3-quartile1
    upperwhisker = 1.5*quartile3
    lowerwhisker = 1.5*quartile1
    train_dataset[variable] = np.where(train_dataset[variable]>upperwhisker,quartile3,train_dataset[variable])
    train_dataset[variable] = np.where(train_dataset[variable]<lowerwhisker,quartile1,train_dataset[variable])

def outliers_doctor_test(variable):
    quartile1 = test_dataset[variable].quantile(0.25)
    print(quartile1)
    quartile3 = test_dataset[variable].quantile(0.75)
    IQR = quartile3-quartile1
    upperwhisker = 1.5*quartile3
    lowerwhisker = 1.5*quartile1
    test_dataset[variable] = np.where(test_dataset[variable]>upperwhisker,quartile3,test_dataset[variable])
    test_dataset[variable] = np.where(test_dataset[variable]<lowerwhisker,quartile1,test_dataset[variable])


for j in outlierfeatnum:
    outliers_doctor_train(j)
    outliers_doctor_test(j)
# Out:
# 2875.5
# 2864.0
# 0.0
# 0.0

# %%
train_dataset.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       611.000000         611.000000  611.000000        611.000000
# mean       4069.513093        1134.669263  146.369492        342.324059
# std        1570.560643        1119.792938   84.240750         64.208419
# min        2875.500000           0.000000    9.000000         12.000000
# 25%        2875.500000           0.000000  100.000000        360.000000
# 50%        2875.500000        1213.000000  128.000000        360.000000
# 75%        5785.000000        2303.000000  165.000000        360.000000
# max        8666.000000        3449.000000  700.000000        480.000000
#
#        Credit_History  Loan_Status  LoanAmountlog
# count      611.000000   611.000000     611.000000
# mean         0.854337     0.685761       4.861175
# std          0.353057     0.464592       0.497624
# min          0.000000     0.000000       2.197225
# 25%          1.000000     0.000000       4.605170
# ...

# %%
test_dataset.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  367.000000        367.000000
# mean       3788.196185        1176.656676  136.272064        342.822888
# std        1260.432799        1173.531472   60.957624         64.658402
# min        2864.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  101.000000        360.000000
# 50%        2864.000000        1025.000000  126.000000        360.000000
# 75%        5059.000000        2423.750000  157.500000        360.000000
# max        7500.000000        3583.000000  550.000000        480.000000
#
#        Credit_History  LoanAmountlog
# count      367.000000     367.000000
# mean         0.839237       4.829169
# std          0.367814       0.416599
# min          0.000000       3.332205
# 25%          1.000000       4.615121
# 50%          1.000000       4.836282
# 75%          1.000000       5.059420
# ...

# %%
figure1 = plt.figure(figsize=(20,10))
axes1 = figure1.add_subplot(221)
plt.boxplot(train_dataset['ApplicantIncome'],vert=False)
plt.title('Applicant Income',fontname="Times New Roman Bold")

axes2 = figure1.add_subplot(222)
plt.boxplot(train_dataset['CoapplicantIncome'],vert=False)
plt.title('Coapplicant Income',fontname="Times New Roman Bold")
# Out:
# Text(0.5, 1.0, 'Coapplicant Income')

# %%
train_dataset['Loan_Amount_Term'].value_counts().sort_index()
# Out:
# 12.0       1
# 36.0       2
# 60.0       2
# 84.0       4
# 120.0      3
# 180.0     44
# 240.0      3
# 300.0     13
# 360.0    525
# 480.0     14
# Name: Loan_Amount_Term, dtype: int64

# %%
test_dataset['Loan_Amount_Term'].value_counts().sort_index()
# Out:
# 6.0        1
# 12.0       1
# 36.0       1
# 60.0       1
# 84.0       3
# 120.0      1
# 180.0     22
# 240.0      4
# 300.0      7
# 350.0      1
# 360.0    317
# 480.0      8
# Name: Loan_Amount_Term, dtype: int64

# %%
# sns.distplot(train_dataset['Loan_Amount_Term'])

# %% [markdown]
# # Feature Extraction

# %%
train_dataset['Loan_Amount_Term'] = np.where(train_dataset['Loan_Amount_Term']<120,180,train_dataset['Loan_Amount_Term'])
test_dataset['Loan_Amount_Term'] = np.where(test_dataset['Loan_Amount_Term']<120,180,test_dataset['Loan_Amount_Term'])

# %%
sns.distplot(train_dataset['Loan_Amount_Term'])
# Out:
# <AxesSubplot:xlabel='Loan_Amount_Term'>

# %%
sns.distplot(test_dataset['Loan_Amount_Term'])
# Out:
# <AxesSubplot:xlabel='Loan_Amount_Term'>

# %%
train_dataset.Loan_Amount_Term.value_counts().sort_index()
# Out:
# 120.0      3
# 180.0     53
# 240.0      3
# 300.0     13
# 360.0    525
# 480.0     14
# Name: Loan_Amount_Term, dtype: int64

# %%
for i in dataset:    
    i['Loan_Amount_Term_years'] = round(i['Loan_Amount_Term']/12)
    i.drop(columns= 'Loan_Amount_Term', inplace=True)

# %%
train_dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Credit_History  \
# 0           5849.0                0.0  146.369492             1.0
# 1           4583.0             1508.0  128.000000             1.0
# 2           2875.5                0.0   66.000000             1.0
# 3           2875.5             2358.0  120.000000             1.0
# 4           6000.0                0.0  141.000000             1.0
#
#   Property_Area  Loan_Status  LoanAmountlog  Loan_Amount_Term_years
# 0         Urban            1       4.986134                    30.0
# ...

# %%
train_dataset.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Credit_History', 'Property_Area', 'Loan_Status', 'LoanAmountlog',
#        'Loan_Amount_Term_years'],
#       dtype='object')

# %%
test_dataset.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Credit_History', 'Property_Area', 'LoanAmountlog',
#        'Loan_Amount_Term_years'],
#       dtype='object')

# %%
train_dataset.Loan_Amount_Term_years.value_counts()
# Out:
# 30.0    525
# 15.0     53
# 40.0     14
# 25.0     13
# 20.0      3
# 10.0      3
# Name: Loan_Amount_Term_years, dtype: int64

# %%
test_dataset.Loan_Amount_Term_years.value_counts()
# Out:
# 30.0    317
# 15.0     29
# 40.0      8
# 25.0      7
# 20.0      4
# 10.0      1
# 29.0      1
# Name: Loan_Amount_Term_years, dtype: int64

# %%
train_dataset.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes          3      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Credit_History  \
# 0           5849.0                0.0  146.369492             1.0
# 1           4583.0             1508.0  128.000000             1.0
# ...

# %%
for i in dataset:
    i['LoanAmount'] = round(i['LoanAmount'])

# %%
train_dataset.head(20)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes          3      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate            No
# 12  LP001028    Male     Yes          2      Graduate            No
# ...

# %%
test_dataset.LoanAmount.max()
# Out:
# 550.0

# %%
bins = [0,200,400,700]
labels = [1,2,3]

for i in dataset:
    i['LoanAmountBin'] = pd.cut(i['LoanAmount'],bins=bins,labels=labels)

# %%
test_dataset.LoanAmountBin.value_counts()
# Out:
# 1    337
# 2     27
# 3      3
# Name: LoanAmountBin, dtype: int64

# %%
train_dataset.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes          3      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Credit_History  \
# 0           5849.0                0.0       146.0             1.0
# 1           4583.0             1508.0       128.0             1.0
# ...

# %%
sns.heatmap(train_dataset.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
train_dataset.CoapplicantIncome.value_counts()
# Out:
# 0.0       271
# 2304.0     72
# 2500.0      5
# 2083.0      5
# 1666.0      5
#          ...
# 1793.0      1
# 2200.0      1
# 1742.0      1
# 1126.0      1
# 2845.0      1
# Name: CoapplicantIncome, Length: 224, dtype: int64

# %%
labinrel = pd.crosstab(train_dataset['LoanAmountBin'],train_dataset['Loan_Status'],normalize=True)*100
labinrel
# Out:
# Loan_Status            0          1
# LoanAmountBin
# 1              26.350245  60.556465
# 2               4.418985   6.382979
# 3               0.654664   1.636661

# %%
labinrel.plot(kind="bar",stacked=True,figsize=(10,7))
# Out:
# <AxesSubplot:xlabel='LoanAmountBin'>

# %%
sns.distplot(train_dataset['ApplicantIncome'],color="blue")
# Out:
# <AxesSubplot:xlabel='ApplicantIncome'>

# %%
bins = [2000,4000,7000,9000]
labels = [1,2,3]

for i in dataset:
    i['ApplicantIncomebins'] = pd.cut(i['ApplicantIncome'],bins=bins,labels=labels)

# %%
train_dataset.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes          3      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Credit_History  \
# 0           5849.0                0.0       146.0             1.0
# 1           4583.0             1508.0       128.0             1.0
# ...

# %%
test_dataset.head(10)
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001015    Male     Yes          0      Graduate            No
# 1  LP001022    Male     Yes          1      Graduate            No
# 2  LP001031    Male     Yes          2      Graduate            No
# 3  LP001035    Male     Yes          2      Graduate            No
# 4  LP001051    Male      No          0  Not Graduate            No
# 5  LP001054    Male     Yes          0  Not Graduate           Yes
# 6  LP001055  Female      No          1  Not Graduate            No
# 7  LP001056    Male     Yes          2  Not Graduate            No
# 8  LP001059    Male     Yes          2      Graduate            No
# 9  LP001067    Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Credit_History  \
# 0           5720.0                0.0       110.0             1.0
# 1           2864.0             1500.0       126.0             1.0
# ...

# %%
pd.crosstab(train_dataset['ApplicantIncomebins'],train_dataset['Loan_Status'],normalize=True)*100
# Out:
# Loan_Status                  0          1
# ApplicantIncomebins
# 1                    18.003273  41.407529
# 2                    12.111293  23.404255
# 3                     1.309329   3.764321

# %%
pd.crosstab(train_dataset['ApplicantIncome'],train_dataset['Loan_Status'],normalize=True)*100
# Out:
# Loan_Status              0          1
# ApplicantIncome
# 2875.5           18.003273  41.407529
# 4333.0            0.327332   0.163666
# 4342.0            0.000000   0.163666
# 4344.0            0.163666   0.000000
# 4350.0            0.000000   0.163666
# ...                    ...        ...
# 8333.0            0.000000   0.654664
# 8334.0            0.163666   0.000000
# 8566.0            0.000000   0.163666
# 8624.0            0.000000   0.163666
# 8666.0            0.163666   0.000000
#
# [147 rows x 2 columns]

# %%
train_dataset.Self_Employed.describe()
# Out:
# count     611
# unique      2
# top        No
# freq      529
# Name: Self_Employed, dtype: object

# %%
pd.crosstab(train_dataset['Self_Employed'],train_dataset['Loan_Status'],normalize=True)*100
# Out:
# Loan_Status            0          1
# Self_Employed
# No             27.168576  59.410802
# Yes             4.255319   9.165303

# %%
train_dataset['ApplicantIncome'].min()
# Out:
# 2875.5

# %%
for df in dataset:
    df['LoanApproval_adv'] = np.where(((df['Gender'] == 'Male') & (df['Married'] == 'Yes') & (df['Education'] == 'Graduate') & (df['Credit_History'] == 1.0)),1,0)

# %%
test_dataset.head(10)
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001015    Male     Yes          0      Graduate            No
# 1  LP001022    Male     Yes          1      Graduate            No
# 2  LP001031    Male     Yes          2      Graduate            No
# 3  LP001035    Male     Yes          2      Graduate            No
# 4  LP001051    Male      No          0  Not Graduate            No
# 5  LP001054    Male     Yes          0  Not Graduate           Yes
# 6  LP001055  Female      No          1  Not Graduate            No
# 7  LP001056    Male     Yes          2  Not Graduate            No
# 8  LP001059    Male     Yes          2      Graduate            No
# 9  LP001067    Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Credit_History  \
# 0           5720.0                0.0       110.0             1.0
# 1           2864.0             1500.0       126.0             1.0
# ...

# %%
pd.crosstab(train_dataset['LoanApproval_adv'],train_dataset['Loan_Status'])
# Out:
# Loan_Status         0    1
# LoanApproval_adv
# 0                 152  209
# 1                  40  210

# %%
for i in dataset:
    i['EMI'] = i['LoanAmount']/(i['Loan_Amount_Term_years']/12)
    i['EMI_adv'] = np.where((i['ApplicantIncome']/i['EMI'])<70,1,0)

# %%
train_dataset.EMI_adv.value_counts()
# Out:
# 1    315
# 0    296
# Name: EMI_adv, dtype: int64

# %%
train_dataset.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes          3      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Credit_History  \
# 0           5849.0                0.0       146.0             1.0
# 1           4583.0             1508.0       128.0             1.0
# ...

# %%
pd.crosstab(train_dataset['LoanApproval_adv'],train_dataset['EMI_adv'],normalize=True)*100
# Out:
# EMI_adv                   0          1
# LoanApproval_adv
# 0                 30.441899  28.641571
# 1                 18.003273  22.913257

# %%
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 611 entries, 0 to 613
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Loan_ID                 611 non-null    object
#  1   Gender                  611 non-null    object
#  2   Married                 611 non-null    object
#  3   Dependents              611 non-null    object
#  4   Education               611 non-null    object
#  5   Self_Employed           611 non-null    object
#  6   ApplicantIncome         611 non-null    float64
#  7   CoapplicantIncome       611 non-null    float64
#  8   LoanAmount              611 non-null    float64
#  9   Credit_History          611 non-null    float64
#  10  Property_Area           611 non-null    object
#  11  Loan_Status             611 non-null    int64
#  12  LoanAmountlog           611 non-null    float64
#  13  Loan_Amount_Term_years  611 non-null    float64
# ...

# %%
for i in dataset:
    i.drop(columns="Loan_ID",axis=1,inplace=True)

# %%
for i in dataset:
    i.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 611 entries, 0 to 613
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Gender                  611 non-null    object
#  1   Married                 611 non-null    object
#  2   Dependents              611 non-null    object
#  3   Education               611 non-null    object
#  4   Self_Employed           611 non-null    object
#  5   ApplicantIncome         611 non-null    float64
#  6   CoapplicantIncome       611 non-null    float64
#  7   LoanAmount              611 non-null    float64
#  8   Credit_History          611 non-null    float64
#  9   Property_Area           611 non-null    object
#  10  Loan_Status             611 non-null    int64
#  11  LoanAmountlog           611 non-null    float64
#  12  Loan_Amount_Term_years  611 non-null    float64
#  13  LoanAmountBin           611 non-null    category
# ...

# %% [markdown]
# # Onehot Encoding

# %%
train_dataset_copy = train_dataset.copy()
test_dataset_copy = test_dataset.copy()

# %%
object_columns = ["Gender","Married","Dependents","Education","Self_Employed","Property_Area"]

for j in dataset:
    for i in object_columns:
        j[i] = j[i].astype('category')

# %%
for i in dataset:
    i.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 611 entries, 0 to 613
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Gender                  611 non-null    category
#  1   Married                 611 non-null    category
#  2   Dependents              611 non-null    category
#  3   Education               611 non-null    category
#  4   Self_Employed           611 non-null    category
#  5   ApplicantIncome         611 non-null    float64
#  6   CoapplicantIncome       611 non-null    float64
#  7   LoanAmount              611 non-null    float64
#  8   Credit_History          611 non-null    float64
#  9   Property_Area           611 non-null    category
#  10  Loan_Status             611 non-null    int64
#  11  LoanAmountlog           611 non-null    float64
#  12  Loan_Amount_Term_years  611 non-null    float64
#  13  LoanAmountBin           611 non-null    category
# ...

# %%
for i in dataset:
    print(i.columns)
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Credit_History',
#        'Property_Area', 'Loan_Status', 'LoanAmountlog',
#        'Loan_Amount_Term_years', 'LoanAmountBin', 'ApplicantIncomebins',
#        'LoanApproval_adv', 'EMI', 'EMI_adv'],
#       dtype='object')
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Credit_History',
#        'Property_Area', 'LoanAmountlog', 'Loan_Amount_Term_years',
#        'LoanAmountBin', 'ApplicantIncomebins', 'LoanApproval_adv', 'EMI',
#        'EMI_adv'],
#       dtype='object')

# %%
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 611 entries, 0 to 613
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Gender                  611 non-null    category
#  1   Married                 611 non-null    category
#  2   Dependents              611 non-null    category
#  3   Education               611 non-null    category
#  4   Self_Employed           611 non-null    category
#  5   ApplicantIncome         611 non-null    float64
#  6   CoapplicantIncome       611 non-null    float64
#  7   LoanAmount              611 non-null    float64
#  8   Credit_History          611 non-null    float64
#  9   Property_Area           611 non-null    category
#  10  Loan_Status             611 non-null    int64
#  11  LoanAmountlog           611 non-null    float64
#  12  Loan_Amount_Term_years  611 non-null    float64
#  13  LoanAmountBin           611 non-null    category
# ...

# %%
test_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Gender                  367 non-null    category
#  1   Married                 367 non-null    category
#  2   Dependents              367 non-null    category
#  3   Education               367 non-null    category
#  4   Self_Employed           367 non-null    category
#  5   ApplicantIncome         367 non-null    float64
#  6   CoapplicantIncome       367 non-null    float64
#  7   LoanAmount              367 non-null    float64
#  8   Credit_History          367 non-null    float64
#  9   Property_Area           367 non-null    category
#  10  LoanAmountlog           367 non-null    float64
#  11  Loan_Amount_Term_years  367 non-null    float64
#  12  LoanAmountBin           367 non-null    category
#  13  ApplicantIncomebins     367 non-null    category
# ...

# %%
train_columns = train_dataset.columns
test_columns = test_dataset.columns

# %%
categorical_columns = ["Gender","Married","Dependents","Education","Self_Employed","Property_Area","LoanAmountBin","ApplicantIncomebins"]
categorical_dataset_train = train_dataset.select_dtypes(include=['category'])

print(categorical_dataset_train.head(10))

categorical_dataset_test = test_dataset.select_dtypes(include=['category'])

print(categorical_dataset_test.head(10))
# Out:
#   Gender Married Dependents     Education Self_Employed Property_Area  \
# 0   Male      No          0      Graduate            No         Urban
# 1   Male     Yes          1      Graduate            No         Rural
# 2   Male     Yes          0      Graduate           Yes         Urban
# 3   Male     Yes          0  Not Graduate            No         Urban
# 4   Male      No          0      Graduate            No         Urban
# 5   Male     Yes          2      Graduate           Yes         Urban
# 6   Male     Yes          0  Not Graduate            No         Urban
# 7   Male     Yes          3      Graduate            No     Semiurban
# 8   Male     Yes          2      Graduate            No         Urban
# 9   Male     Yes          1      Graduate            No     Semiurban
#
#   LoanAmountBin ApplicantIncomebins
# 0             1                   2
# 1             1                   2
# 2             1                   1
# 3             1                   1
# ...

# %%
dummy_cat_train = pd.get_dummies(categorical_dataset_train, drop_first=True)

dummy_cat_test = pd.get_dummies(categorical_dataset_test, drop_first=True)

for i in dataset:
    for j in categorical_columns:
        i.drop([j], axis=1, inplace=True)
        
train_dataset = pd.concat([train_dataset,dummy_cat_train],axis=1)
test_dataset = pd.concat([test_dataset,dummy_cat_test],axis=1)

# %%
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 611 entries, 0 to 613
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ApplicantIncome          611 non-null    float64
#  1   CoapplicantIncome        611 non-null    float64
#  2   LoanAmount               611 non-null    float64
#  3   Credit_History           611 non-null    float64
#  4   Loan_Status              611 non-null    int64
#  5   LoanAmountlog            611 non-null    float64
#  6   Loan_Amount_Term_years   611 non-null    float64
#  7   LoanApproval_adv         611 non-null    int32
#  8   EMI                      611 non-null    float64
#  9   EMI_adv                  611 non-null    int32
#  10  Gender_Male              611 non-null    uint8
#  11  Married_Yes              611 non-null    uint8
#  12  Dependents_0             611 non-null    uint8
#  13  Dependents_1             611 non-null    uint8
# ...

# %%
test_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ApplicantIncome          367 non-null    float64
#  1   CoapplicantIncome        367 non-null    float64
#  2   LoanAmount               367 non-null    float64
#  3   Credit_History           367 non-null    float64
#  4   LoanAmountlog            367 non-null    float64
#  5   Loan_Amount_Term_years   367 non-null    float64
#  6   LoanApproval_adv         367 non-null    int32
#  7   EMI                      367 non-null    float64
#  8   EMI_adv                  367 non-null    int32
#  9   Gender_Male              367 non-null    uint8
#  10  Married_Yes              367 non-null    uint8
#  11  Dependents_0             367 non-null    uint8
#  12  Dependents_1             367 non-null    uint8
#  13  Dependents_2             367 non-null    uint8
# ...

# %%
correlation_matrix = train_dataset.corr()
figure = plt.figure(figsize=(30,20))
sns.heatmap(correlation_matrix, annot=True,vmax=.8,cmap="coolwarm",square=True, figure=figure)
# Out:
# <AxesSubplot:>

# %%
train_dataset.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Credit_History  \
# 0           5849.0                0.0       146.0             1.0
# 1           4583.0             1508.0       128.0             1.0
# 2           2875.5                0.0        66.0             1.0
# 3           2875.5             2358.0       120.0             1.0
# 4           6000.0                0.0       141.0             1.0
#
#    Loan_Status  LoanAmountlog  Loan_Amount_Term_years  LoanApproval_adv   EMI  \
# 0            1       4.986134                    30.0                 0  58.4
# 1            0       4.852030                    30.0                 1  51.2
# 2            1       4.189655                    30.0                 1  26.4
# 3            1       4.787492                    30.0                 0  48.0
# 4            1       4.948760                    30.0                 0  56.4
#
#    EMI_adv  ...  Dependents_1  Dependents_2  Education_Not Graduate  \
# ...

# %%
train_columns = train_dataset.columns.to_list()
train_columns
train_dataset = train_dataset[['ApplicantIncome',
 'CoapplicantIncome',
 'LoanAmount',
 'Credit_History',
 'LoanAmountlog',
 'Loan_Amount_Term_years',
 'LoanApproval_adv',
 'EMI',
 'EMI_adv',
 'Gender_Male',
 'Married_Yes',
 'Dependents_0',
 'Dependents_1',
 'Dependents_2',
 'Education_Not Graduate',
 'Self_Employed_Yes',
 'Property_Area_Semiurban',
 'Property_Area_Urban',
 'LoanAmountBin_2',
 'LoanAmountBin_3',
 'ApplicantIncomebins_2',
 'ApplicantIncomebins_3','Loan_Status']]

# %%
train_dataset.head(10)
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Credit_History  \
# 0           5849.0                0.0       146.0             1.0
# 1           4583.0             1508.0       128.0             1.0
# 2           2875.5                0.0        66.0             1.0
# 3           2875.5             2358.0       120.0             1.0
# 4           6000.0                0.0       141.0             1.0
# 5           5417.0             2304.0       267.0             1.0
# 6           2875.5             1516.0        95.0             1.0
# 7           2875.5             2504.0       158.0             0.0
# 8           2875.5             1526.0       168.0             1.0
# 9           5790.0             2304.0       349.0             1.0
#
#    LoanAmountlog  Loan_Amount_Term_years  LoanApproval_adv    EMI  EMI_adv  \
# 0       4.986134                    30.0                 0   58.4        0
# 1       4.852030                    30.0                 1   51.2        0
# ...

# %%
correlation_matrix = train_dataset.corr()
figure = plt.figure(figsize=(30,20))
sns.heatmap(correlation_matrix, annot=True,vmax=.8,cmap="coolwarm",square=True, figure=figure)
# Out:
# <AxesSubplot:>

# %%
train_dataset.drop(columns=["LoanAmount"],axis=1,inplace=True)
test_dataset.drop(columns=["LoanAmount"],axis=1,inplace=True)

# %%
train_dataset
# Out:
#      ApplicantIncome  CoapplicantIncome  Credit_History  LoanAmountlog  \
# 0             5849.0                0.0             1.0       4.986134
# 1             4583.0             1508.0             1.0       4.852030
# 2             2875.5                0.0             1.0       4.189655
# 3             2875.5             2358.0             1.0       4.787492
# 4             6000.0                0.0             1.0       4.948760
# ..               ...                ...             ...            ...
# 609           2875.5                0.0             1.0       4.262680
# 610           2875.5                0.0             1.0       3.688879
# 611           8072.0              240.0             1.0       5.533389
# 612           7583.0                0.0             1.0       5.231109
# 613           4583.0                0.0             0.0       4.890349
#
#      Loan_Amount_Term_years  LoanApproval_adv    EMI  EMI_adv  Gender_Male  \
# ...

# %%
test_dataset.head(10)
# Out:
#    ApplicantIncome  CoapplicantIncome  Credit_History  LoanAmountlog  \
# 0           5720.0                0.0             1.0       4.700480
# 1           2864.0             1500.0             1.0       4.836282
# 2           5000.0             1800.0             1.0       5.337538
# 3           2864.0             2546.0             1.0       4.605170
# 4           2864.0                0.0             1.0       4.356709
# 5           2864.0             3422.0             1.0       5.023881
# 6           2864.0                0.0             1.0       4.077537
# 7           2864.0                0.0             0.0       4.990433
# 8           5060.0                0.0             1.0       5.634790
# 9           2864.0             2400.0             1.0       4.812184
#
#    Loan_Amount_Term_years  LoanApproval_adv    EMI  EMI_adv  Gender_Male  \
# 0                    30.0                 1   44.0        0            1
# ...

# %% [markdown]
# # Feature Selection

# %%
array = train_dataset.values
predictor = array[:,0:21]
target = array[:,21]

logistic_model = LogisticRegression()
rfe = RFE(logistic_model,7)
fit = rfe.fit(predictor,target)

print("Num Features: %s" % (fit.n_features_))
print("Selected Features: %s" % (fit.support_))
features = fit.ranking_.tolist()
arr = np.array(features)
bool_arr = arr == 1
output_feature_index = np.where(bool_arr)[0]
output_feature_index
# Out:
# c:\users\saravanan\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_features_to_select=7 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# c:\users\saravanan\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Num Features: 7
# Selected Features: [False False  True False False  True False False False False False  True
# ...

# %%
train_columns = train_dataset.columns
selected_features = []
for j in output_feature_index:
    for index,i in enumerate(train_columns): 
        if (index == j):
            selected_features.append(i)

# %%
selected_features
# Out:
# ['Credit_History',
#  'LoanApproval_adv',
#  'Dependents_1',
#  'Dependents_2',
#  'Property_Area_Semiurban',
#  'LoanAmountBin_2',
#  'ApplicantIncomebins_3']

# %%
train_df = train_dataset.copy()
test_df = test_dataset.copy()

# %%
train_df_cols = train_df.columns.tolist()

# %%
train_df_cols.remove('Loan_Status')

# %%
train_df_cols
# Out:
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'Credit_History',
#  'LoanAmountlog',
#  'Loan_Amount_Term_years',
#  'LoanApproval_adv',
#  'EMI',
#  'EMI_adv',
#  'Gender_Male',
#  'Married_Yes',
#  'Dependents_0',
#  'Dependents_1',
#  'Dependents_2',
#  'Education_Not Graduate',
#  'Self_Employed_Yes',
#  'Property_Area_Semiurban',
#  'Property_Area_Urban',
#  'LoanAmountBin_2',
#  'LoanAmountBin_3',
#  'ApplicantIncomebins_2',
#  'ApplicantIncomebins_3']

# %%
drop_cols = np.setdiff1d(train_df_cols,selected_features)

# %%
drop_cols
# Out:
# array(['ApplicantIncome', 'ApplicantIncomebins_2', 'CoapplicantIncome',
#        'Dependents_0', 'EMI', 'EMI_adv', 'Education_Not Graduate',
#        'Gender_Male', 'LoanAmountBin_3', 'LoanAmountlog',
#        'Loan_Amount_Term_years', 'Married_Yes', 'Property_Area_Urban',
#        'Self_Employed_Yes'], dtype='<U23')

# %%
selected_features
# Out:
# ['Credit_History',
#  'LoanApproval_adv',
#  'Dependents_1',
#  'Dependents_2',
#  'Property_Area_Semiurban',
#  'LoanAmountBin_2',
#  'ApplicantIncomebins_3']

# %%
dataset_df = [train_df,test_df]
len(train_df.columns)
len(test_df.columns)
# Out:
# 21

# %%
for i in dataset_df:
    for j in drop_cols:
        i.drop(columns=[j],axis=1,inplace=True)

# %%
train_df
# Out:
#      Credit_History  LoanApproval_adv  Dependents_1  Dependents_2  \
# 0               1.0                 0             0             0
# 1               1.0                 1             1             0
# 2               1.0                 1             0             0
# 3               1.0                 0             0             0
# 4               1.0                 0             0             0
# ..              ...               ...           ...           ...
# 609             1.0                 0             0             0
# 610             1.0                 1             0             0
# 611             1.0                 1             1             0
# 612             1.0                 1             0             1
# 613             0.0                 0             0             0
#
#      Property_Area_Semiurban  LoanAmountBin_2  ApplicantIncomebins_3  \
# 0                          0                0                      0
# ...

# %%
test_df
# Out:
#      Credit_History  LoanApproval_adv  Dependents_1  Dependents_2  \
# 0               1.0                 1             0             0
# 1               1.0                 1             1             0
# 2               1.0                 1             0             1
# 3               1.0                 1             0             1
# 4               1.0                 0             0             0
# ..              ...               ...           ...           ...
# 362             1.0                 0             0             0
# 363             1.0                 1             0             0
# 364             1.0                 0             0             0
# 365             1.0                 1             0             0
# 366             1.0                 0             0             0
#
#      Property_Area_Semiurban  LoanAmountBin_2  ApplicantIncomebins_3
# 0                          0                0                      0
# ...

# %% [markdown]
# # Logistic Regression Model

# %%
logimode_gscv = LogisticRegression()
X = train_df.iloc[:,0:7]
Y = train_df.iloc[:,7]

param_grid_lr = {'solver':["liblinear","newton-cg","lbfgs"],'penalty': ["l1", "l2","elasticnet"],'C':[0.001,0.01,0.1,1]}
logitmode_cv = GridSearchCV(logimode_gscv,param_grid=param_grid_lr,verbose=1,scoring='accuracy',n_jobs=-1)
best_lrpc = logitmode_cv.fit(X,Y)
print(logitmode_cv.best_estimator_) 

"""
randformode = RandomForestRegressor()
param_rand_rf = {"n_estimators": [int(i) for i in np.linspace(100,1000,10)],
                "max_features":['auto', 'sqrt'],
                 "min_samples_split": [int (i) for i in np.linspace(2,10,5)],
                 "min_samples_leaf" : [1,2,3],
                 "bootstrap" : [True,False]
                }
randfor_cv = RandomizedSearchCV(estimator=randformode,param_distributions=param_rand_rf,cv=3,verbose=2,random_state=123,n_jobs=-1)
best_rfpc = randfor_cv.fit(X,Y)
print("Random Forest Parameter Combination: ", best_rfpc.best_estimator_)"""
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.4s
# LogisticRegression(C=1, penalty='l1', solver='liblinear')
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:    2.7s finished
# '\nrandformode = RandomForestRegressor()\nparam_rand_rf = {"n_estimators": [int(i) for i in np.linspace(100,1000,10)],\n                "max_features":[\'auto\', \'sqrt\'],\n                 "min_samples_split": [int (i) for i in np.linspace(2,10,5)],\n                 "min_samples_leaf" : [1,2,3],\n                 "bootstrap" : [True,False]\n                }\nrandfor_cv = RandomizedSearchCV(estimator=randformode,param_distributions=param_rand_rf,cv=3,verbose=2,random_state=123,n_jobs=-1)\nbest_rfpc = randfor_cv.fit(X,Y)\nprint("Random Forest Parameter Combination: ", best_rfpc.best_estimator_)'

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.20,random_state = 123)

# %%
X_train
# Out:
#      Credit_History  LoanApproval_adv  Dependents_1  Dependents_2  \
# 452             0.0                 0             0             0
# 34              1.0                 0             0             0
# 334             1.0                 1             1             0
# 365             1.0                 0             0             0
# 33              1.0                 1             0             0
# ..              ...               ...           ...           ...
# 98              1.0                 0             0             0
# 324             1.0                 1             0             0
# 384             1.0                 1             0             1
# 367             0.0                 0             0             0
# 513             1.0                 1             0             0
#
#      Property_Area_Semiurban  LoanAmountBin_2  ApplicantIncomebins_3
# 452                        0                0                      0
# ...

# %%
X_test
# Out:
#      Credit_History  LoanApproval_adv  Dependents_1  Dependents_2  \
# 78              0.0                 0             0             0
# 11              1.0                 1             0             1
# 312             1.0                 0             0             0
# 284             1.0                 1             0             0
# 102             1.0                 1             0             0
# ..              ...               ...           ...           ...
# 254             0.0                 0             0             0
# 135             1.0                 1             0             0
# 178             1.0                 1             1             0
# 266             1.0                 1             0             1
# 495             1.0                 0             1             0
#
#      Property_Area_Semiurban  LoanAmountBin_2  ApplicantIncomebins_3
# 78                         1                0                      0
# ...

# %%
Y_train
# Out:
# 452    0
# 34     0
# 334    1
# 365    0
# 33     1
#       ..
# 98     1
# 324    1
# 384    0
# 367    0
# 513    0
# Name: Loan_Status, Length: 488, dtype: int64

# %%
Y_test
# Out:
# 78     0
# 11     1
# 312    1
# 284    0
# 102    1
#       ..
# 254    0
# 135    0
# 178    1
# 266    1
# 495    1
# Name: Loan_Status, Length: 123, dtype: int64

# %%
"""logimode = LogisticRegression(C=1,penalty= "l1", solver ="liblinear")
trained_model = logimode.fit(X_train,Y_train)
pred = trained_model.predict(X_test)"""
# Out:
# 'logimode = LogisticRegression(C=1,penalty= "l1", solver ="liblinear")\ntrained_model = logimode.fit(X_train,Y_train)\npred = trained_model.predict(X_test)'

# %%
#print("Accuracy:",accuracy_score(Y_test, pred))

# %%
#print(classification_report(Y_test, pred))

# %%
#Randfor_model = RandomForestClassifier(max_features='sqrt', min_samples_leaf=3, min_samples_split=6, n_estimators=700)
#randforfit = Randfor_model.fit(X_train,Y_train)
#rand_pred = randforfit.predict(X_test)

# %%
#print("Accuracy:",accuracy_score(Y_test, rand_pred))

# %%
#XGB Parameter
"""
xgb_model_cv = xgb.XGBClassifier()
param_grid_xgb = {"learning_rate" : [0.0001, 0.001, 0.01, 0.1, 0.2],
             "n_estimators" : [100, 200, 300, 400, 500],
             "max_depth":[1,2,3,4,5],
             "subsample":[0.1,0.3,0.5,0.7]
             }
xgb_cv = GridSearchCV(xgb_model_cv,param_grid=param_grid_xgb,verbose=2,scoring='accuracy',n_jobs=-1)
best_xgbpc = xgb_cv.fit(X,Y)
print(best_xgbpc.best_estimator_)"""


xgb_model = xgb.XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
              importance_type='gain', interaction_constraints='',
              learning_rate=0.01, max_delta_step=0, max_depth=5,
              min_child_weight=1, monotone_constraints='()',
              n_estimators=300, n_jobs=0, num_parallel_tree=1, random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.7,
              tree_method='exact', validate_parameters=1, verbosity=None)
xgbmodel_fit = xgb_model.fit(X_train,Y_train)
xgb_predict = xgbmodel_fit.predict(X_test)
print("Accuracy:",accuracy_score(Y_test,xgb_predict))
# Out:
# Accuracy: 0.8130081300813008
